# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import seaborn as sb

# %%
df = pd.read_csv('Datasets\SampleSuperstore.csv')

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
max(df['Profit'])
# Out:
# 8399.976

# %%
new_df = df.sort_values(by=['Profit'], ascending= False)

# %%
new_df
# Out:
#            Ship Mode      Segment        Country         City           State  \
# 6826  Standard Class    Corporate  United States    Lafayette         Indiana
# 8153     First Class     Consumer  United States      Seattle      Washington
# 4190  Standard Class     Consumer  United States       Newark        Delaware
# 9039  Standard Class     Consumer  United States      Detroit        Michigan
# 4098  Standard Class     Consumer  United States  Minneapolis       Minnesota
# ...              ...          ...            ...          ...             ...
# 4991  Standard Class    Corporate  United States      Chicago        Illinois
# 3011  Standard Class  Home Office  United States   Louisville        Colorado
# 9774  Standard Class     Consumer  United States  San Antonio           Texas
# 683         Same Day    Corporate  United States   Burlington  North Carolina
# 7772  Standard Class     Consumer  United States    Lancaster            Ohio
#
# ...

# %%
new_df.boxplot(column= ['Sales'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
new_df.boxplot(column= ['Quantity'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
new_df.boxplot(column= ['Profit'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
new_df.groupby('Category')['Profit', 'Sales'].agg(['sum']) .plot.bar()
plt.show()
# Out:
# <ipython-input-13-1ed003a5d061>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   new_df.groupby('Category')['Profit', 'Sales'].agg(['sum']) .plot.bar()

# %%
plt.figure(figsize=(10, 10))
new_df.groupby('Sub-Category')['Profit', 'Sales'].agg(['sum']) .plot.bar()
plt.show()
# Out:
# <ipython-input-15-b61b83cf257f>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   new_df.groupby('Sub-Category')['Profit', 'Sales'].agg(['sum']) .plot.bar()

# %%
sb.barplot(x= new_df.Region, y= new_df.Profit, hue=new_df.Category)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>
