# %%
import yfinance as yf
import datetime
import pandas_datareader.data as web
import os
import pandas as pd 
import matplotlib.pyplot as plt
# print(datetime.date.today())

# %%
def reload():
    os.remove("Datasets/google.csv")
    finance()
    
def finance():
    symbol = 'GOOGL'
    ticker = yf.Ticker(symbol)
    # print(ticker)
    ticker_df = ticker.history(period= '1M', interval= '1D',start= '2021-05-15', end=datetime.date.today())
    ticker_df.to_csv('Datasets/google.csv')
    print('CSV has been initialised!')

# %%
finance()
# Out:
# CSV has been initialised!

# %%
df = pd.read_csv('Datasets\google.csv', parse_dates= True, index_col=0)

# %%
df
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2021-05-14  2258.540039  2284.719971  2250.000000  2278.379883  1599800
# 2021-05-17  2263.570068  2289.780029  2255.510010  2288.919922  1079900
# 2021-05-18  2302.350098  2307.679932  2262.189941  2262.469971  1110200
# 2021-05-19  2228.429932  2274.989990  2225.439941  2271.500000  1184200
# 2021-05-20  2291.000000  2312.000000  2283.520020  2306.949951  1617600
# 2021-05-21  2317.409912  2318.889893  2289.300049  2294.129883  2031600
# 2021-05-24  2314.889893  2365.550049  2311.959961  2361.040039  1591600
# 2021-05-25  2372.000000  2384.000000  2355.000000  2362.870117  1122000
# 2021-05-26  2366.520020  2388.989990  2366.459961  2380.310059  1078600
# 2021-05-27  2389.050049  2389.050049  2356.260010  2362.679932  1761200
# 2021-05-28  2374.419922  2376.070068  2352.850098  2356.850098  1074100
# 2021-06-01  2374.439941  2385.709961  2354.280029  2381.179932  1167700
# ...

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
df.plot()
plt.show()

# %%
df = pd.read_csv('Datasets\google.csv')

# %%
plt.plot(df.Date, df.Close)
plt.xticks(rotation = 90)
plt.xlabel('Dates')
plt.ylabel('Closed Stocks')
plt.title('Actual CLosed Data')
plt.grid(True)
plt.show()
