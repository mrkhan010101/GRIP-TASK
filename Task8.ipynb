# %%
import datetime
import os
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Datasets\covid_19_india.csv', parse_dates= True, index_col=1)

# %%
df
# Out:
#               Sno     Time          State ConfirmedIndianNational  \
# Date
# 2020-01-30      1  6:00 PM         Kerala                       1
# 2020-01-31      2  6:00 PM         Kerala                       1
# 2020-02-01      3  6:00 PM         Kerala                       2
# 2020-02-02      4  6:00 PM         Kerala                       3
# 2020-02-03      5  6:00 PM         Kerala                       3
# ...           ...      ...            ...                     ...
# 2021-05-19  15082  8:00 AM      Telangana                       -
# 2021-05-19  15083  8:00 AM        Tripura                       -
# 2021-05-19  15084  8:00 AM    Uttarakhand                       -
# 2021-05-19  15085  8:00 AM  Uttar Pradesh                       -
# 2021-05-19  15086  8:00 AM    West Bengal                       -
#
#            ConfirmedForeignNational    Cured  Deaths  Confirmed
# Date
# 2020-01-30                        0        0       0          1
# ...

# %%
df.plot()
plt.show()

# %%
df = pd.read_csv('Datasets\covid_19_india.csv')

# %%
df
# Out:
#          Sno        Date     Time          State ConfirmedIndianNational  \
# 0          1  2020-01-30  6:00 PM         Kerala                       1
# 1          2  2020-01-31  6:00 PM         Kerala                       1
# 2          3  2020-02-01  6:00 PM         Kerala                       2
# 3          4  2020-02-02  6:00 PM         Kerala                       3
# 4          5  2020-02-03  6:00 PM         Kerala                       3
# ...      ...         ...      ...            ...                     ...
# 15081  15082  2021-05-19  8:00 AM      Telangana                       -
# 15082  15083  2021-05-19  8:00 AM        Tripura                       -
# 15083  15084  2021-05-19  8:00 AM    Uttarakhand                       -
# 15084  15085  2021-05-19  8:00 AM  Uttar Pradesh                       -
# 15085  15086  2021-05-19  8:00 AM    West Bengal                       -
#
#       ConfirmedForeignNational    Cured  Deaths  Confirmed
# ...

# %%
df.groupby('State')['Cured','Deaths','Confirmed'].agg('sum')
# Out:
# <ipython-input-4-0c5278659954>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('State')['Cured','Deaths','Confirmed'].agg('sum')
#                                                 Cured    Deaths  Confirmed
# State
# Andaman and Nicobar Islands                   1248991     16725    1322379
# Andhra Pradesh                              222440263   1904323  237393872
# Arunachal Pradesh                             3802671     12494    4092625
# Assam                                        54208616    273151   58376235
# Bihar                                        67677104    403867   73454827
# Cases being reassigned to states                    0         0     345565
# Chandigarh                                    5119517     81515    5723372
# Chhattisgarh                                 71048526    945876   80759266
# ...

# %%
df.groupby('State')['Cured','Deaths','Confirmed'].agg(['sum']).plot(kind = 'bar')
plt.show()
# Out:
# <ipython-input-7-f63de0a7b364>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('State')['Cured','Deaths','Confirmed'].agg(['sum']).plot(kind = 'bar')

# %%
df.groupby('State')['Cured'].agg(['sum']).plot(kind = 'bar')
plt.legend(['Cured'])
plt.grid('True')
plt.show()

# %%
df.groupby('State')['Deaths'].agg(['sum']).plot(kind = 'bar')
plt.legend(['Deaths'])
plt.grid('True')
plt.show()

# %%
df.groupby('State')['Confirmed'].agg(['sum']).plot(kind = 'bar')
plt.legend(['Confirmed'])
plt.grid('True')
plt.show()

# %%
df.groupby('Date')['Confirmed'].agg(['sum']).plot(kind = 'line')
plt.title('Corona Wave')
plt.legend(['Confirmed'])
plt.grid('True')
plt.show()

# %%
df.groupby('Date')['Cured'].agg(['sum']).plot(kind = 'line')
plt.title('Corona Wave')
plt.legend(['Cured'])
plt.grid('True')
plt.show()

# %%
df.groupby('Date')['Deaths'].agg(['sum']).plot(kind = 'line')
plt.title('Corona Wave')
plt.legend(['Deaths'])
plt.grid('True')
plt.show()
